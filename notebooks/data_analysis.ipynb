# %%
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
np.set_printoptions(suppress=True, precision=3)

# %%
import pandas as pd

ds = pd.read_csv('./../data/train.csv', index_col='id')
ds
# Out:
#                                   belongs_to_collection    budget  \
# id
# 1     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 3                                                   NaN   3300000
# 4                                                   NaN   1200000
# 5                                                   NaN         0
# ...                                                 ...       ...
# 2996                                                NaN         0
# 2997                                                NaN         0
# 2998                                                NaN  65000000
# 2999                                                NaN  42000000
# 3000                                                NaN  35000000
#
#                                                  genres  \
# id
# 1                        [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
from kowalsky.df import describe_missing_values
describe_missing_values(ds)

# %%
btc = ds.belongs_to_collection[~ds.belongs_to_collection.isnull()]

trans_ix = btc[btc.str.contains('Transformers', regex=False)].index
ds[ds.index.isin(trans_ix)]
# Out:
#                                   belongs_to_collection     budget  \
# id
# 1152  [{'id': 8650, 'name': 'Transformers Collection...  150000000
# 1333  [{'id': 8650, 'name': 'Transformers Collection...  150000000
# 1631  [{'id': 8650, 'name': 'Transformers Collection...  260000000
# 2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
#
#                                                  genres  \
# id
# 1152  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1333  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1631  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2323  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                                homepage    imdb_id original_language  \
# id
# 1152  http://www.transformersmovie.com/  tt0418279                en
# 1333  http://www.transformersmovie.com/  tt1055369                en
# 1631  http://www.transformersmovie.com/  tt3371366                en
# ...

# %%
import seaborn as sns

sns.displot(ds.budget)

# %%
sns.displot(ds.popularity)

# %%
sns.displot(ds.runtime)

# %%
ds.status.astype('object').unique()
# Out:
# array(['Released', 'Rumored'], dtype=object)

# %%
ds[ds.status == 'Rumored']
# Out:
#                                   belongs_to_collection  budget  \
# id
# 610   [{'id': 144200, 'name': 'Swan Princess Series'...       0
# 1008                                                NaN       0
# 1217                                                NaN       0
# 1619                                                NaN  891000
#
#                                                  genres homepage    imdb_id  \
# id
# 610   [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...      NaN  tt0120254
# 1008                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt1860180
# 1217  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN  tt0091024
# 1619                [{'id': 99, 'name': 'Documentary'}]      NaN  tt0145394
#
#      original_language                                  original_title  \
# id
# 610                 en  The Swan Princess: Escape from Castle Mountain
# 1008                en                         Billy Gardell: Halftime
# ...

# %%
ds[ds.title != ds.original_title]
# Out:
#      belongs_to_collection    budget  \
# id
# 5                      NaN         0
# 16                     NaN    500000
# 31                     NaN  13000000
# 46                     NaN   3906840
# 51                     NaN    560000
# ...                    ...       ...
# 2964                   NaN         0
# 2973                   NaN         0
# 2981                   NaN    300000
# 2989                   NaN         0
# 2997                   NaN         0
#
#                                                  genres  \
# id
# 5     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 16    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 31    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 46    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# ...                                                 ...
# 2964  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# ...

# %%
sns.displot(ds.revenue)
